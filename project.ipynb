# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
data=pd.read_csv('covid_data_2025.csv')

# %%
state=data['State/UT']
cases=data['Active Cases (Total)']
death=data['Deaths (Total)']

#sort the data firstly zip the data and then sort them
combined=sorted(zip(cases,state,death))
scases,sstate,sdeath=zip(*combined)


plt.LogFormatter(True)
bars=plt.barh(sstate,scases)

plt.title("Total Covid cases in year 2025 ")
plt.xlabel("death")
plt.ylabel("State and union territories")
plt.legend()
for i,bar in enumerate(bars):
    plt.text(bar.get_width()+5,
             bar.get_y()+bar.get_height()/2,
             sdeath[i],
             va='center',fontsize=8,label='deaths')
# Out:
# C:\Users\shukl\AppData\Local\Temp\ipykernel_12936\3735916027.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
data.sort_values('Deaths (Total)',ascending=False,inplace=True)

# %%
data.head(10)
# Out:
#     S. No.        State/UT  Active Cases (Total)  Active Cases (Change)  \
# 15      16     Maharashtra                   494                     12
# 13      14          Kerala                  1416                     19
# 6        7           Delhi                   393                     90
# 12      13       Karnataka                   311                     58
# 22      23      Tamil Nadu                   215                     26
# 25      26   Uttar Pradesh                   138                     19
# 20      21       Rajasthan                    75                      6
# 14      15  Madhya Pradesh                    21                      2
# 19      20          Punjab                     9                      3
# 8        9         Gujarat                   397                     59
#
#     Cured (Total)  Cured (Change)  Deaths (Total)  Deaths (Change)
# 15            369              69              10                2
# 13            888             171               9                1
# 6             563             124               4                0
# 12            214              29               4                0
# 22            239               4               3                1
# 25             39              26               2                0
# 20             37               9               1                0
# 14              7               3               1                0
# 19              5               2               1                0
# 8             156              36               1                0

# %%
filtered_df=data[data['Deaths (Total)']>=2]
plt.style.use('ggplot')
states_name=filtered_df['State/UT']
active_cases=filtered_df['Active Cases (Total)']
colors=['#e5ae37','#008fd5','#fc4f30','#6d9042',"#0E5762","#bdbd3f"]
explode=[0,0.02,0,0,0,0]
plt.pie(active_cases,labels=states_name,colors=colors,autopct='%1.1f%%',startangle=25,explode=explode,wedgeprops={'edgecolor':"#444444"})
plt.title("Covid Cases-2025",fontsize=16,color="#0B0000",fontweight='bold',style='oblique')
plt.show()
